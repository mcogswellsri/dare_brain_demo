# %%
from matplotlib import colors
import matplotlib.pyplot as plt
import numpy as np

# %%
import matplotlib.cm as cm

# %%
fig = plt.figure(figsize=(10, 10))
ax = plt.gca()

norm = colors.Normalize(vmin=0., vmax=1.)
viridis = cm.get_cmap('viridis')

fig.colorbar(cm.ScalarMappable(norm=norm, cmap=viridis), ax=ax, orientation='horizontal')

# %%
img = plt.imread('colorbar.png')
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 602.5, 76.5, -0.5)

# %%
fig = plt.figure(figsize=(10, 10))
ax = plt.gca()

norm = colors.Normalize(vmin=-1., vmax=1.)
cmap = 'coolwarm'

fig.colorbar(cm.ScalarMappable(norm=norm, cmap=cmap), ax=ax, orientation='horizontal')

# %%
img = plt.imread('div_colormap.png')
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 1427.5, 181.5, -0.5)
